# %%
import pandas as pd

# %%
df1 = pd.read_excel('C://Users//DanukaDilshanRathnay//Desktop//AI-Driven-Job-Role-Fit-Prediction//code//Dataset//Similarity_with_EMP_data.xlsx')
df1.head()
# Out:
#   EmployeeCode  Technical Score_JD  Programming Score_JD  Soft Score_with_JD  \
# 0      EMP9004            0.257062              0.667620            0.468664
# 1      EMP9005            0.171806              0.543745            0.468005
# 2      EMP9009            0.237569              0.667620            0.509374
# 3      EMP9015            0.253079              0.646303            0.453373
# 4      EMP9021            0.163569              0.646303            0.418016
#
#    Education_match_Score_with_JD  Gender  Age   Department     JobCategory  \
# 0                       0.573545    Male   41  Data and AI  Data Scientist
# 1                       0.648808  Female   33  Data and AI   Data Engineer
# 2                       0.675198    Male   35  Data and AI  Data Scientist
# 3                       0.634185    Male   42  Data and AI  Data Scientist
# 4                       0.721195    Male   59  Data and AI    Data Analyst
#
#   ProficiencyLevel  ... Total Experience in Years  Number of Goal Assigned  \
# 0           Senior  ...                        19                       10
# 1        Mid-Level  ...                        11                       10
# 2        Mid-Level  ...                        13                        7
# 3           Senior  ...                        20                       10
# 4           Expert  ...                        37                       15
#
#   Number of Goals Achieved Final Score Goals Score  Competency Score  \
# 0                        7   35.000000   70.000000         34.180251
# 1                        5   35.000000   50.000000         30.775600
# 2                        3   35.000000   42.857143         20.708582
# 3                        5   35.000000   50.000000         18.998407
# 4                       11   56.717347   73.333333         32.126666
#
#    Cultural Value Score  Additional Accomplishment Score  \
# 0             76.488103                             7.08
# 1             63.895969                             1.63
# 2             57.979997                             8.01
# 3             66.495545                             5.71
# 4             78.174790                             2.63
#
#    Potential Assessment Score  Trait Assessment Score
# 0                   51.806653               55.141563
# 1                   40.425636               54.988743
# 2                   30.443135               36.977535
# 3                   43.893732               45.595596
# 4                   61.771810               50.283365
#
# [5 rows x 29 columns]

# %%
df=df1[df1["Department"]=="Data and AI"]
df.head()
# Out:
#   EmployeeCode  Technical Score_JD  Programming Score_JD  Soft Score_with_JD  \
# 0      EMP9004            0.257062              0.667620            0.468664
# 1      EMP9005            0.171806              0.543745            0.468005
# 2      EMP9009            0.237569              0.667620            0.509374
# 3      EMP9015            0.253079              0.646303            0.453373
# 4      EMP9021            0.163569              0.646303            0.418016
#
#    Education_match_Score_with_JD  Gender  Age   Department     JobCategory  \
# 0                       0.573545    Male   41  Data and AI  Data Scientist
# 1                       0.648808  Female   33  Data and AI   Data Engineer
# 2                       0.675198    Male   35  Data and AI  Data Scientist
# 3                       0.634185    Male   42  Data and AI  Data Scientist
# 4                       0.721195    Male   59  Data and AI    Data Analyst
#
#   ProficiencyLevel  ... Total Experience in Years  Number of Goal Assigned  \
# 0           Senior  ...                        19                       10
# 1        Mid-Level  ...                        11                       10
# 2        Mid-Level  ...                        13                        7
# 3           Senior  ...                        20                       10
# 4           Expert  ...                        37                       15
#
#   Number of Goals Achieved Final Score Goals Score  Competency Score  \
# 0                        7   35.000000   70.000000         34.180251
# 1                        5   35.000000   50.000000         30.775600
# 2                        3   35.000000   42.857143         20.708582
# 3                        5   35.000000   50.000000         18.998407
# 4                       11   56.717347   73.333333         32.126666
#
#    Cultural Value Score  Additional Accomplishment Score  \
# 0             76.488103                             7.08
# 1             63.895969                             1.63
# 2             57.979997                             8.01
# 3             66.495545                             5.71
# 4             78.174790                             2.63
#
#    Potential Assessment Score  Trait Assessment Score
# 0                   51.806653               55.141563
# 1                   40.425636               54.988743
# 2                   30.443135               36.977535
# 3                   43.893732               45.595596
# 4                   61.771810               50.283365
#
# [5 rows x 29 columns]

# %%
df.shape
# Out:
# (240, 29)

# %%
employee_ids = df["EmployeeCode"]

df = df.drop(columns=["EmployeeCode"])

# %%
df.columns
# Out:
# Index(['Technical Score_JD', 'Programming Score_JD', 'Soft Score_with_JD',
#        'Education_match_Score_with_JD', 'Gender', 'Age', 'Department',
#        'JobCategory', 'ProficiencyLevel', 'Education Qualifications',
#        'Years of Experience in this Company', 'List of Software Skills',
#        'Projects Completed', 'Professional Qualifications', 'KPI',
#        'Absentism Rate', 'Employee Satisfaction Score',
#        'Experience in Years Previous Positions', 'Total Experience in Years',
#        'Number of Goal Assigned', 'Number of Goals Achieved', 'Final Score',
#        'Goals Score', 'Competency Score', 'Cultural Value Score',
#        'Additional Accomplishment Score', 'Potential Assessment Score',
#        'Trait Assessment Score'],
#       dtype='object')

# %%
un_col=['Gender','Department', 'JobCategory', 'ProficiencyLevel',
       'Education Qualifications', 'Professional Qualifications','Final Score','Age','List of Software Skills','Number of Goal Assigned', 'Number of Goals Achieved','Projects Completed',"Total Experience in Years","Absentism Rate"]
df_n=df.drop(columns=un_col)

# %%
df_n.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 14 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Technical Score_JD                      240 non-null    float64
#  1   Programming Score_JD                    240 non-null    float64
#  2   Soft Score_with_JD                      240 non-null    float64
#  3   Education_match_Score_with_JD           240 non-null    float64
#  4   Years of Experience in this Company     240 non-null    int64
#  5   KPI                                     240 non-null    float64
#  6   Employee Satisfaction Score             240 non-null    float64
#  7   Experience in Years Previous Positions  240 non-null    int64
#  8   Goals Score                             240 non-null    float64
#  9   Competency Score                        240 non-null    float64
#  10  Cultural Value Score                    240 non-null    float64
#  11  Additional Accomplishment Score         240 non-null    float64
#  12  Potential Assessment Score              240 non-null    float64
#  13  Trait Assessment Score                  240 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 26.4 KB

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler
sd=StandardScaler()
mn=MinMaxScaler()

# %%
df_con=sd.fit_transform(df_n)
df_con=pd.DataFrame(df_con,columns=df_n.columns)
df_con.head()
# Out:
#    Technical Score_JD  Programming Score_JD  Soft Score_with_JD  \
# 0            0.513790              0.646515            0.741535
# 1           -0.919798             -0.451721            0.733751
# 2            0.186014              0.646515            1.222497
# 3            0.446811              0.457528            0.560877
# 4           -1.058308              0.457528            0.143155
#
#    Education_match_Score_with_JD  Years of Experience in this Company  \
# 0                      -0.880730                            -0.590303
# 1                       0.312989                            -0.455248
# 2                       0.731556                            -0.995468
# 3                       0.081058                            -0.995468
# 4                       1.461114                             0.625192
#
#         KPI  Employee Satisfaction Score  \
# 0 -0.233031                     0.276858
# 1 -0.471827                    -1.028983
# 2 -1.425184                     0.269708
# 3 -1.265382                    -0.666101
# 4  1.658107                     1.505833
#
#    Experience in Years Previous Positions  Goals Score  Competency Score  \
# 0                                0.597193     0.639453          0.728677
# 1                               -0.516742    -0.396366          0.357783
# 2                                0.225881    -0.766302         -0.738894
# 3                                1.092276    -0.396366         -0.925196
# 4                                1.711129     0.812089          0.504965
#
#    Cultural Value Score  Additional Accomplishment Score  \
# 0              0.884639                         0.656303
# 1             -0.461913                        -1.204903
# 2             -1.094544                         0.973903
# 3             -0.183925                         0.188440
# 4              1.065007                        -0.863398
#
#    Potential Assessment Score  Trait Assessment Score
# 0                    0.436509                0.462198
# 1                   -0.334448                0.444873
# 2                   -1.010668               -1.597004
# 3                   -0.099517               -0.620000
# 4                    1.111555               -0.088562

# %% [markdown]
# ### PCA

# %%
from sklearn.decomposition import PCA
import numpy as np
import matplotlib.pyplot as plt

# %%
df_con.head()
# Out:
#    Technical Score_JD  Programming Score_JD  Soft Score_with_JD  \
# 0            0.513790              0.646515            0.741535
# 1           -0.919798             -0.451721            0.733751
# 2            0.186014              0.646515            1.222497
# 3            0.446811              0.457528            0.560877
# 4           -1.058308              0.457528            0.143155
#
#    Education_match_Score_with_JD  Years of Experience in this Company  \
# 0                      -0.880730                            -0.590303
# 1                       0.312989                            -0.455248
# 2                       0.731556                            -0.995468
# 3                       0.081058                            -0.995468
# 4                       1.461114                             0.625192
#
#         KPI  Employee Satisfaction Score  \
# 0 -0.233031                     0.276858
# 1 -0.471827                    -1.028983
# 2 -1.425184                     0.269708
# 3 -1.265382                    -0.666101
# 4  1.658107                     1.505833
#
#    Experience in Years Previous Positions  Goals Score  Competency Score  \
# 0                                0.597193     0.639453          0.728677
# 1                               -0.516742    -0.396366          0.357783
# 2                                0.225881    -0.766302         -0.738894
# 3                                1.092276    -0.396366         -0.925196
# 4                                1.711129     0.812089          0.504965
#
#    Cultural Value Score  Additional Accomplishment Score  \
# 0              0.884639                         0.656303
# 1             -0.461913                        -1.204903
# 2             -1.094544                         0.973903
# 3             -0.183925                         0.188440
# 4              1.065007                        -0.863398
#
#    Potential Assessment Score  Trait Assessment Score
# 0                    0.436509                0.462198
# 1                   -0.334448                0.444873
# 2                   -1.010668               -1.597004
# 3                   -0.099517               -0.620000
# 4                    1.111555               -0.088562

# %%
pca=PCA()
pca.fit(df_con)
# Out:
# PCA()

# %%
eigenvalues=pca.explained_variance_
print(eigenvalues)
# Out:
# [3.65911996 2.43917849 1.4046136  1.17700872 1.01807232 1.00041382
#  0.94461265 0.71108706 0.65672666 0.33351478 0.29758271 0.22093416
#  0.12921368 0.0664988 ]

# %%
n_components = np.sum(eigenvalues > 1)
print(f"Number of components with eigenvalue > 1: {n_components}")

# Optional: Plot the eigenvalues to visualize the decision
plt.plot(range(1, len(eigenvalues) + 1), eigenvalues, marker='o')
plt.axhline(y=1, color='r', linestyle='--')  # Draw line at eigenvalue = 1
plt.xlabel('Component Number')
plt.ylabel('Eigenvalue')
plt.title('Eigenvalue vs Component Number (Kaiser Criterion)')
plt.show()
# Out:
# Number of components with eigenvalue > 1: 6

# %%
total_va=(eigenvalues[:n_components].sum()/eigenvalues.sum())*100
print(total_va)
# Out:
# 76.09878719982355

# %%
explain=pca.explained_variance_ratio_
print(explain)
# Out:
# [0.26027669 0.17350109 0.0999115  0.08372175 0.07241645 0.07116039
#  0.0671912  0.0505803  0.04671359 0.02372322 0.02116734 0.01571526
#  0.00919109 0.00473012]

# %%
eigenvector=pca.components_
print(eigenvector.shape)
eigen_df=pd.DataFrame(eigenvector,columns=[f'PCA{i+1}' for i in range(df_con.shape[1])])
eigen_df.head(5)
# Out:
# (14, 14)
#        PCA1      PCA2      PCA3      PCA4      PCA5      PCA6      PCA7  \
# 0  0.022921 -0.081334  0.008372 -0.069541  0.321228  0.441823  0.159015
# 1 -0.042999  0.000118  0.083108  0.086594  0.007787 -0.053109  0.522486
# 2  0.631019 -0.602850  0.347430 -0.210976 -0.041520 -0.023787 -0.012665
# 3 -0.057263  0.066578  0.071063  0.085429 -0.566600  0.029163  0.208992
# 4  0.137712  0.344577  0.127932  0.454289  0.090614  0.010106 -0.061407
#
#        PCA8      PCA9     PCA10     PCA11     PCA12     PCA13     PCA14
# 0  0.147835  0.413995  0.433097  0.169811  0.039480  0.448822  0.227193
# 1 -0.114802 -0.248691 -0.092344  0.566429 -0.027991 -0.232307  0.498726
# 2 -0.016649 -0.030193 -0.074952 -0.027411  0.244496 -0.046309  0.035184
# 3  0.611566  0.240850 -0.276011  0.127297  0.244341  0.148571 -0.090513
# 4 -0.270162 -0.001986  0.085455  0.018783  0.737954  0.026595 -0.039295

# %%
selected_eigenvectors = pd.DataFrame(eigenvector[:,:n_components], columns=[f'PCA{i+1}' for i in range(n_components)])
selected_eigenvectors.head()
# Out:
#        PCA1      PCA2      PCA3      PCA4      PCA5      PCA6
# 0  0.022921 -0.081334  0.008372 -0.069541  0.321228  0.441823
# 1 -0.042999  0.000118  0.083108  0.086594  0.007787 -0.053109
# 2  0.631019 -0.602850  0.347430 -0.210976 -0.041520 -0.023787
# 3 -0.057263  0.066578  0.071063  0.085429 -0.566600  0.029163
# 4  0.137712  0.344577  0.127932  0.454289  0.090614  0.010106

# %%
selected=eigenvalues[:n_components]
print(selected)
# Out:
# [3.65911996 2.43917849 1.4046136  1.17700872 1.01807232 1.00041382]

# %%
Normalize_eigenvector = np.abs(selected_eigenvectors) / np.sum(np.abs(selected_eigenvectors))
Normalize_eigenvector
# Out:
# c:\Users\DanukaDilshanRathnay\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\_core\fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
#         PCA1      PCA2      PCA3      PCA4      PCA5      PCA6
# 0   0.009121  0.032829  0.003416  0.028715  0.127994  0.194214
# 1   0.017110  0.000047  0.033914  0.035757  0.003103  0.023345
# 2   0.251091  0.243331  0.141775  0.087117  0.016544  0.010456
# 3   0.022786  0.026873  0.028998  0.035276  0.225763  0.012819
# 4   0.054797  0.139083  0.052205  0.187586  0.036106  0.004442
# 5   0.064634  0.024628  0.290195  0.173578  0.067782  0.077859
# 6   0.132722  0.109223  0.187138  0.295796  0.002240  0.024547
# 7   0.101005  0.051108  0.119525  0.067068  0.169236  0.070343
# 8   0.236368  0.250480  0.083036  0.037163  0.021540  0.072601
# 9   0.027459  0.013161  0.005261  0.021275  0.039392  0.059682
# 10  0.046842  0.045443  0.030710  0.001458  0.016850  0.361277
# 11  0.011522  0.016387  0.016623  0.019182  0.230599  0.046479
# 12  0.020757  0.046599  0.004715  0.003758  0.031225  0.039145
# 13  0.003787  0.000806  0.002490  0.006270  0.011628  0.002790

# %%
selected_ra=eigenvalues[:n_components]/eigenvalues.sum()
print(selected_ra)
# Out:
# [0.26027669 0.17350109 0.0999115  0.08372175 0.07241645 0.07116039]

# %%
eigen_loadings = pd.DataFrame(Normalize_eigenvector.values, index=df_con.columns, columns=[f'pca{i+1}' for i in range(n_components)])
eigen_loadings.head(21)
# Out:
#                                             pca1      pca2      pca3  \
# Technical Score_JD                      0.009121  0.032829  0.003416
# Programming Score_JD                    0.017110  0.000047  0.033914
# Soft Score_with_JD                      0.251091  0.243331  0.141775
# Education_match_Score_with_JD           0.022786  0.026873  0.028998
# Years of Experience in this Company     0.054797  0.139083  0.052205
# KPI                                     0.064634  0.024628  0.290195
# Employee Satisfaction Score             0.132722  0.109223  0.187138
# Experience in Years Previous Positions  0.101005  0.051108  0.119525
# Goals Score                             0.236368  0.250480  0.083036
# Competency Score                        0.027459  0.013161  0.005261
# Cultural Value Score                    0.046842  0.045443  0.030710
# Additional Accomplishment Score         0.011522  0.016387  0.016623
# Potential Assessment Score              0.020757  0.046599  0.004715
# Trait Assessment Score                  0.003787  0.000806  0.002490
#
#                                             pca4      pca5      pca6
# Technical Score_JD                      0.028715  0.127994  0.194214
# Programming Score_JD                    0.035757  0.003103  0.023345
# Soft Score_with_JD                      0.087117  0.016544  0.010456
# Education_match_Score_with_JD           0.035276  0.225763  0.012819
# Years of Experience in this Company     0.187586  0.036106  0.004442
# KPI                                     0.173578  0.067782  0.077859
# Employee Satisfaction Score             0.295796  0.002240  0.024547
# Experience in Years Previous Positions  0.067068  0.169236  0.070343
# Goals Score                             0.037163  0.021540  0.072601
# Competency Score                        0.021275  0.039392  0.059682
# Cultural Value Score                    0.001458  0.016850  0.361277
# Additional Accomplishment Score         0.019182  0.230599  0.046479
# Potential Assessment Score              0.003758  0.031225  0.039145
# Trait Assessment Score                  0.006270  0.011628  0.002790

# %%
def generate_pca_equation_dict(loadings_array, feature_names):
    # Convert to DataFrame for ease of processing
    loading_df = pd.DataFrame(loadings_array, columns=[f"PCA{i+1}" for i in range(loadings_array.shape[1])], index=feature_names)

    pca_equation_dict = {}

    # Iterate through each PCA component
    for pca in loading_df.columns:
        terms = []
        for feature, loading in loading_df[pca].items():
            terms.append(f"{loading:.5f} * df_con['{feature}']")  # Format coefficients
        equation = " + ".join(terms)
        pca_equation_dict[pca] = equation

    return pca_equation_dict


# Generate the equation dictionary
feature_names = eigen_loadings.index  # Ensure correct feature names
pca_equations = generate_pca_equation_dict(eigen_loadings.values, feature_names)

# Print the generated PCA equations
for pca, eq in pca_equations.items():
    print(f"{pca}= {eq}\n")
# Out:
# PCA1= 0.00912 * df_con['Technical Score_JD'] + 0.01711 * df_con['Programming Score_JD'] + 0.25109 * df_con['Soft Score_with_JD'] + 0.02279 * df_con['Education_match_Score_with_JD'] + 0.05480 * df_con['Years of Experience in this Company'] + 0.06463 * df_con['KPI'] + 0.13272 * df_con['Employee Satisfaction Score'] + 0.10100 * df_con['Experience in Years Previous Positions'] + 0.23637 * df_con['Goals Score'] + 0.02746 * df_con['Competency Score'] + 0.04684 * df_con['Cultural Value Score'] + 0.01152 * df_con['Additional Accomplishment Score'] + 0.02076 * df_con['Potential Assessment Score'] + 0.00379 * df_con['Trait Assessment Score']
#
# PCA2= 0.03283 * df_con['Technical Score_JD'] + 0.00005 * df_con['Programming Score_JD'] + 0.24333 * df_con['Soft Score_with_JD'] + 0.02687 * df_con['Education_match_Score_with_JD'] + 0.13908 * df_con['Years of Experience in this Company'] + 0.02463 * df_con['KPI'] + 0.10922 * df_con['Employee Satisfaction Score'] + 0.05111 * df_con['Experience in Years Previous Positions'] + 0.25048 * df_con['Goals Score'] + 0.01316 * df_con['Competency Score'] + 0.04544 * df_con['Cultural Value Score'] + 0.01639 * df_con['Additional Accomplishment Score'] + 0.04660 * df_con['Potential Assessment Score'] + 0.00081 * df_con['Trait Assessment Score']
#
# PCA3= 0.00342 * df_con['Technical Score_JD'] + 0.03391 * df_con['Programming Score_JD'] + 0.14177 * df_con['Soft Score_with_JD'] + 0.02900 * df_con['Education_match_Score_with_JD'] + 0.05220 * df_con['Years of Experience in this Company'] + 0.29019 * df_con['KPI'] + 0.18714 * df_con['Employee Satisfaction Score'] + 0.11952 * df_con['Experience in Years Previous Positions'] + 0.08304 * df_con['Goals Score'] + 0.00526 * df_con['Competency Score'] + 0.03071 * df_con['Cultural Value Score'] + 0.01662 * df_con['Additional Accomplishment Score'] + 0.00471 * df_con['Potential Assessment Score'] + 0.00249 * df_con['Trait Assessment Score']
#
# PCA4= 0.02871 * df_con['Technical Score_JD'] + 0.03576 * df_con['Programming Score_JD'] + 0.08712 * df_con['Soft Score_with_JD'] + 0.03528 * df_con['Education_match_Score_with_JD'] + 0.18759 * df_con['Years of Experience in this Company'] + 0.17358 * df_con['KPI'] + 0.29580 * df_con['Employee Satisfaction Score'] + 0.06707 * df_con['Experience in Years Previous Positions'] + 0.03716 * df_con['Goals Score'] + 0.02128 * df_con['Competency Score'] + 0.00146 * df_con['Cultural Value Score'] + 0.01918 * df_con['Additional Accomplishment Score'] + 0.00376 * df_con['Potential Assessment Score'] + 0.00627 * df_con['Trait Assessment Score']
#
# PCA5= 0.12799 * df_con['Technical Score_JD'] + 0.00310 * df_con['Programming Score_JD'] + 0.01654 * df_con['Soft Score_with_JD'] + 0.22576 * df_con['Education_match_Score_with_JD'] + 0.03611 * df_con['Years of Experience in this Company'] + 0.06778 * df_con['KPI'] + 0.00224 * df_con['Employee Satisfaction Score'] + 0.16924 * df_con['Experience in Years Previous Positions'] + 0.02154 * df_con['Goals Score'] + 0.03939 * df_con['Competency Score'] + 0.01685 * df_con['Cultural Value Score'] + 0.23060 * df_con['Additional Accomplishment Score'] + 0.03122 * df_con['Potential Assessment Score'] + 0.01163 * df_con['Trait Assessment Score']
#
# PCA6= 0.19421 * df_con['Technical Score_JD'] + 0.02335 * df_con['Programming Score_JD'] + 0.01046 * df_con['Soft Score_with_JD'] + 0.01282 * df_con['Education_match_Score_with_JD'] + 0.00444 * df_con['Years of Experience in this Company'] + 0.07786 * df_con['KPI'] + 0.02455 * df_con['Employee Satisfaction Score'] + 0.07034 * df_con['Experience in Years Previous Positions'] + 0.07260 * df_con['Goals Score'] + 0.05968 * df_con['Competency Score'] + 0.36128 * df_con['Cultural Value Score'] + 0.04648 * df_con['Additional Accomplishment Score'] + 0.03914 * df_con['Potential Assessment Score'] + 0.00279 * df_con['Trait Assessment Score']

# %%
suitability_equations = []

for i, (pca, equation) in enumerate(pca_equations.items()):
    if i < len(selected_ra):
        #suitability = f"{selected_ra[i]:.5f} *  ({equation})"
        suitability = f"({equation})"
        suitability_equations.append(suitability)
        

# Combine all equations into one final equation
final_equation = " + ".join(suitability_equations)

print("Final Suitability Equation:\n", final_equation)
# Out:
# Final Suitability Equation:
#  (0.00912 * df_con['Technical Score_JD'] + 0.01711 * df_con['Programming Score_JD'] + 0.25109 * df_con['Soft Score_with_JD'] + 0.02279 * df_con['Education_match_Score_with_JD'] + 0.05480 * df_con['Years of Experience in this Company'] + 0.06463 * df_con['KPI'] + 0.13272 * df_con['Employee Satisfaction Score'] + 0.10100 * df_con['Experience in Years Previous Positions'] + 0.23637 * df_con['Goals Score'] + 0.02746 * df_con['Competency Score'] + 0.04684 * df_con['Cultural Value Score'] + 0.01152 * df_con['Additional Accomplishment Score'] + 0.02076 * df_con['Potential Assessment Score'] + 0.00379 * df_con['Trait Assessment Score']) + (0.03283 * df_con['Technical Score_JD'] + 0.00005 * df_con['Programming Score_JD'] + 0.24333 * df_con['Soft Score_with_JD'] + 0.02687 * df_con['Education_match_Score_with_JD'] + 0.13908 * df_con['Years of Experience in this Company'] + 0.02463 * df_con['KPI'] + 0.10922 * df_con['Employee Satisfaction Score'] + 0.05111 * df_con['Experience in Years Previous Positions'] + 0.25048 * df_con['Goals Score'] + 0.01316 * df_con['Competency Score'] + 0.04544 * df_con['Cultural Value Score'] + 0.01639 * df_con['Additional Accomplishment Score'] + 0.04660 * df_con['Potential Assessment Score'] + 0.00081 * df_con['Trait Assessment Score']) + (0.00342 * df_con['Technical Score_JD'] + 0.03391 * df_con['Programming Score_JD'] + 0.14177 * df_con['Soft Score_with_JD'] + 0.02900 * df_con['Education_match_Score_with_JD'] + 0.05220 * df_con['Years of Experience in this Company'] + 0.29019 * df_con['KPI'] + 0.18714 * df_con['Employee Satisfaction Score'] + 0.11952 * df_con['Experience in Years Previous Positions'] + 0.08304 * df_con['Goals Score'] + 0.00526 * df_con['Competency Score'] + 0.03071 * df_con['Cultural Value Score'] + 0.01662 * df_con['Additional Accomplishment Score'] + 0.00471 * df_con['Potential Assessment Score'] + 0.00249 * df_con['Trait Assessment Score']) + (0.02871 * df_con['Technical Score_JD'] + 0.03576 * df_con['Programming Score_JD'] + 0.08712 * df_con['Soft Score_with_JD'] + 0.03528 * df_con['Education_match_Score_with_JD'] + 0.18759 * df_con['Years of Experience in this Company'] + 0.17358 * df_con['KPI'] + 0.29580 * df_con['Employee Satisfaction Score'] + 0.06707 * df_con['Experience in Years Previous Positions'] + 0.03716 * df_con['Goals Score'] + 0.02128 * df_con['Competency Score'] + 0.00146 * df_con['Cultural Value Score'] + 0.01918 * df_con['Additional Accomplishment Score'] + 0.00376 * df_con['Potential Assessment Score'] + 0.00627 * df_con['Trait Assessment Score']) + (0.12799 * df_con['Technical Score_JD'] + 0.00310 * df_con['Programming Score_JD'] + 0.01654 * df_con['Soft Score_with_JD'] + 0.22576 * df_con['Education_match_Score_with_JD'] + 0.03611 * df_con['Years of Experience in this Company'] + 0.06778 * df_con['KPI'] + 0.00224 * df_con['Employee Satisfaction Score'] + 0.16924 * df_con['Experience in Years Previous Positions'] + 0.02154 * df_con['Goals Score'] + 0.03939 * df_con['Competency Score'] + 0.01685 * df_con['Cultural Value Score'] + 0.23060 * df_con['Additional Accomplishment Score'] + 0.03122 * df_con['Potential Assessment Score'] + 0.01163 * df_con['Trait Assessment Score']) + (0.19421 * df_con['Technical Score_JD'] + 0.02335 * df_con['Programming Score_JD'] + 0.01046 * df_con['Soft Score_with_JD'] + 0.01282 * df_con['Education_match_Score_with_JD'] + 0.00444 * df_con['Years of Experience in this Company'] + 0.07786 * df_con['KPI'] + 0.02455 * df_con['Employee Satisfaction Score'] + 0.07034 * df_con['Experience in Years Previous Positions'] + 0.07260 * df_con['Goals Score'] + 0.05968 * df_con['Competency Score'] + 0.36128 * df_con['Cultural Value Score'] + 0.04648 * df_con['Additional Accomplishment Score'] + 0.03914 * df_con['Potential Assessment Score'] + 0.00279 * df_con['Trait Assessment Score'])

# %%
processed_df = pd.concat([employee_ids.reset_index(drop=True), df_con], axis=1)

# %%
processed_df ["Suitability_score_PCA"]=eval(final_equation)

# %%
processed_df .shape
# Out:
# (240, 16)

# %%
processed_df ["Suitability_score_scaled_PCA"]=mn.fit_transform(processed_df [["Suitability_score_PCA"]])

# %%
pcadf=processed_df[['EmployeeCode','Suitability_score_PCA','Suitability_score_scaled_PCA']]
pcadf.head()
# Out:
#   EmployeeCode  Suitability_score_PCA  Suitability_score_scaled_PCA
# 0      EMP9004               1.947876                      0.652960
# 1      EMP9005              -2.270365                      0.362316
# 2      EMP9009              -0.882823                      0.457920
# 3      EMP9015              -1.038618                      0.447185
# 4      EMP9021               4.885695                      0.855380

# %%
dfg=pd.read_excel('C://Users//DanukaDilshanRathnay//Desktop//AI-Driven-Job-Role-Fit-Prediction//code//Dataset//Similarity_with_EMP_data.xlsx')

# %%
dfpca=pcadf.merge(dfg, on='EmployeeCode',how='left')

# %%
df1=pd.read_excel('C://Users//DanukaDilshanRathnay//Desktop//AI-Driven-Job-Role-Fit-Prediction//com//x.xlsx')
df2=pd.read_excel('C://Users//DanukaDilshanRathnay//Desktop//AI-Driven-Job-Role-Fit-Prediction//com//x_train.xlsx')

# %%
dfm=pd.concat([df1,df2],axis=0)

# %%
df_jd=dfm[['EmployeeCode','JD match Score']]

# %%
df_jd.head()
# Out:
#   EmployeeCode  JD match Score
# 0      EMP9449        0.653565
# 1      EMP9798        0.627276
# 2      EMP9271        0.606090
# 3      EMP9931        0.498329
# 4      EMP9213        0.562582

# %%
df_my=df_jd.merge(dfpca[['EmployeeCode','Suitability_score_PCA','Suitability_score_scaled_PCA']],on="EmployeeCode")

# %%
df_my.head()
# Out:
#   EmployeeCode  JD match Score  Suitability_score_PCA  \
# 0      EMP9449        0.653565              -0.680949
# 1      EMP9798        0.627276               0.277650
# 2      EMP9271        0.606090               2.220474
# 3      EMP9931        0.498329              -2.585812
# 4      EMP9213        0.562582               0.394709
#
#    Suitability_score_scaled_PCA
# 0                      0.471829
# 1                      0.537878
# 2                      0.671742
# 3                      0.340581
# 4                      0.545944

# %%
df_my["disimilarity"]=1-df_my['JD match Score']

# %%
df_my.columns
# Out:
# Index(['EmployeeCode', 'JD match Score', 'Suitability_score_PCA',
#        'Suitability_score_scaled_PCA', 'disimilarity'],
#       dtype='object')

# %%
x=df_my[['Suitability_score_PCA', 'disimilarity']].corr()
print(x)
# Out:
#                        Suitability_score_PCA  disimilarity
# Suitability_score_PCA               1.000000     -0.230778
# disimilarity                       -0.230778      1.000000

# %%
import seaborn as sns
plt.figure(figsize=(8, 6))  # Adjust figure size
sns.heatmap(x, annot=True, fmt=".2f", linewidths=0.5)
plt.show()

# %%
df_my.to_excel("PCA_score.xlsx",index=False)

# %%
# eigen_loadings=eigen_loadings*selected_ra

# %%
feature_importance = np.abs(eigen_loadings)  # Take absolute value for importance
overall_importance = feature_importance.sum(axis=1)  # Sum across rows (principal components)

# Normalize to percentages
overall_importance_percentages = (overall_importance / overall_importance.sum()) 

# Sort feature importances in descending order
sorted_indices = np.argsort(overall_importance_percentages)[::-1]  # Sort indices in descending order

# Print overall feature importance as percentages with column names in descending order
print("\nOverall Feature Importance (as %):")
for idx in sorted_indices:
    print(f"{df_con.columns[idx]}: {overall_importance[idx]:.2f}")
# Out:
# Overall Feature Importance (as %):
# Employee Satisfaction Score: 0.75
# Soft Score_with_JD: 0.75
# Goals Score: 0.70
# KPI: 0.70
# Experience in Years Previous Positions: 0.58
# Cultural Value Score: 0.50
# Years of Experience in this Company: 0.47
# Technical Score_JD: 0.40
# Education_match_Score_with_JD: 0.35
# Additional Accomplishment Score: 0.34
# Competency Score: 0.17
# Potential Assessment Score: 0.15
# Programming Score_JD: 0.11
# Trait Assessment Score: 0.03
# C:\Users\DanukaDilshanRathnay\AppData\Local\Temp\ipykernel_12316\2056477650.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(f"{df_con.columns[idx]}: {overall_importance[idx]:.2f}")
