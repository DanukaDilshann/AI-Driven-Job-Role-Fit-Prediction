# %%
import pandas as pd

# %%
df1 = pd.read_excel('C://Users//DanukaDilshanRathnay//Desktop//AI-Driven-Job-Role-Fit-Prediction//code//Dataset//Similarity_with_EMP_data.xlsx')
df1.head()
# Out:
#   EmployeeCode  Technical Score_JD  Programming Score_JD  Soft Score_with_JD  \
# 0      EMP9004            0.257062              0.667620            0.468664
# 1      EMP9005            0.171806              0.543745            0.468005
# 2      EMP9009            0.237569              0.667620            0.509374
# 3      EMP9015            0.253079              0.646303            0.453373
# 4      EMP9021            0.163569              0.646303            0.418016
#
#    Education_match_Score_with_JD  Gender  Age   Department     JobCategory  \
# 0                       0.573545    Male   41  Data and AI  Data Scientist
# 1                       0.648808  Female   33  Data and AI   Data Engineer
# 2                       0.675198    Male   35  Data and AI  Data Scientist
# 3                       0.634185    Male   42  Data and AI  Data Scientist
# 4                       0.721195    Male   59  Data and AI    Data Analyst
#
#   ProficiencyLevel  ... Total Experience in Years  Number of Goal Assigned  \
# 0           Senior  ...                        19                       10
# 1        Mid-Level  ...                        11                       10
# 2        Mid-Level  ...                        13                        7
# 3           Senior  ...                        20                       10
# 4           Expert  ...                        37                       15
#
#   Number of Goals Achieved Final Score Goals Score  Competency Score  \
# 0                        7   35.000000   70.000000         34.180251
# 1                        5   35.000000   50.000000         30.775600
# 2                        3   35.000000   42.857143         20.708582
# 3                        5   35.000000   50.000000         18.998407
# 4                       11   56.717347   73.333333         32.126666
#
#    Cultural Value Score  Additional Accomplishment Score  \
# 0             76.488103                             7.08
# 1             63.895969                             1.63
# 2             57.979997                             8.01
# 3             66.495545                             5.71
# 4             78.174790                             2.63
#
#    Potential Assessment Score  Trait Assessment Score
# 0                   51.806653               55.141563
# 1                   40.425636               54.988743
# 2                   30.443135               36.977535
# 3                   43.893732               45.595596
# 4                   61.771810               50.283365
#
# [5 rows x 29 columns]

# %%
df=df1[df1["Department"]=="Data and AI"]
df.head()
# Out:
#    EmployeeCode  Technical Score_JD  Programming Score_JD  Soft Score_with_JD  \
# 3       EMP9004            0.514297              0.722849            0.379506
# 4       EMP9005            0.229454              0.787505            0.420458
# 6       EMP9009            0.413824              0.722849            0.586283
# 9       EMP9015            0.451817              0.539208            0.558488
# 11      EMP9021            0.162984              0.539208            0.382562
#
#     Education_match_Score_with_JD  Gender  Age   Department     JobCategory  \
# 3                        0.614774    Male   41  Data and AI  Data Scientist
# 4                        0.644765  Female   33  Data and AI   Data Engineer
# 6                        0.653466    Male   35  Data and AI  Data Scientist
# 9                        0.661025    Male   42  Data and AI  Data Scientist
# 11                       0.760446    Male   59  Data and AI    Data Analyst
#
#    ProficiencyLevel  ... Total Experience in Years  Number of Goal Assigned  \
# 3            Senior  ...                        19                       10
# 4         Mid-Level  ...                        11                       10
# 6         Mid-Level  ...                        13                        7
# 9            Senior  ...                        20                       10
# 11           Expert  ...                        37                       15
#
#    Number of Goals Achieved Final Score Goals Score  Competency Score  \
# 3                         7   35.000000   70.000000         34.180251
# 4                         5   35.000000   50.000000         30.775600
# 6                         3   35.000000   42.857143         20.708582
# 9                         5   35.000000   50.000000         18.998407
# 11                       11   56.717347   73.333333         32.126666
#
#     Cultural Value Score  Additional Accomplishment Score  \
# 3              76.488103                             7.08
# 4              63.895969                             1.63
# 6              57.979997                             8.01
# 9              66.495545                             5.71
# 11             78.174790                             2.63
#
#     Potential Assessment Score  Trait Assessment Score
# 3                    51.806653               55.141563
# 4                    40.425636               54.988743
# 6                    30.443135               36.977535
# 9                    43.893732               45.595596
# 11                   61.771810               50.283365
#
# [5 rows x 29 columns]

# %%
df.shape
# Out:
# (240, 29)

# %%
employee_ids = df["EmployeeCode"]

df = df.drop(columns=["EmployeeCode"])


# # Reassign Employee Codes
# df["EmployeeCode"] = employee_codes

# %%
df.columns
# Out:
# Index(['Technical Score_JD', 'Programming Score_JD', 'Soft Score_with_JD',
#        'Education_match_Score_with_JD', 'Gender', 'Age', 'Department',
#        'JobCategory', 'ProficiencyLevel', 'Education Qualifications',
#        'Years of Experience in this Company', 'List of Software Skills',
#        'Projects Completed', 'Professional Qualifications', 'KPI',
#        'Absentism Rate', 'Employee Satisfaction Score',
#        'Experience in Years Previous Positions', 'Total Experience in Years',
#        'Number of Goal Assigned', 'Number of Goals Achieved', 'Final Score',
#        'Goals Score', 'Competency Score', 'Cultural Value Score',
#        'Additional Accomplishment Score', 'Potential Assessment Score',
#        'Trait Assessment Score'],
#       dtype='object')

# %%
un_col=['Gender','Department', 'JobCategory', 'ProficiencyLevel',
       'Education Qualifications', 'Professional Qualifications','Final Score','Age','List of Software Skills','Number of Goal Assigned', 'Number of Goals Achieved','Projects Completed',"Total Experience in Years","Absentism Rate"]
df_n=df.drop(columns=un_col)

# %%
df_n.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 240 entries, 3 to 498
# Data columns (total 14 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Technical Score_JD                      240 non-null    float64
#  1   Programming Score_JD                    240 non-null    float64
#  2   Soft Score_with_JD                      240 non-null    float64
#  3   Education_match_Score_with_JD           240 non-null    float64
#  4   Years of Experience in this Company     240 non-null    int64
#  5   KPI                                     240 non-null    float64
#  6   Employee Satisfaction Score             240 non-null    float64
#  7   Experience in Years Previous Positions  240 non-null    int64
#  8   Goals Score                             240 non-null    float64
#  9   Competency Score                        240 non-null    float64
#  10  Cultural Value Score                    240 non-null    float64
#  11  Additional Accomplishment Score         240 non-null    float64
#  12  Potential Assessment Score              240 non-null    float64
#  13  Trait Assessment Score                  240 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 28.1 KB

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler
sd=StandardScaler()
mn=MinMaxScaler()

# %%
df_con=sd.fit_transform(df_n)
df_con=pd.DataFrame(df_con,columns=df_n.columns)
df_con.head()
# Out:
#    Technical Score_JD  Programming Score_JD  Soft Score_with_JD  \
# 0            1.565223              0.111923           -0.227219
# 1           -0.340456              0.388721            0.214140
# 2            0.893030              0.111923            2.001321
# 3            1.147216             -0.674252            1.701759
# 4           -0.785155             -0.674252           -0.194284
#
#    Education_match_Score_with_JD  Years of Experience in this Company  \
# 0                      -0.421820                            -0.590303
# 1                       0.108914                            -0.455248
# 2                       0.262900                            -0.995468
# 3                       0.396675                            -0.995468
# 4                       2.156105                             0.625192
#
#         KPI  Employee Satisfaction Score  \
# 0 -0.233031                     0.276858
# 1 -0.471827                    -1.028983
# 2 -1.425184                     0.269708
# 3 -1.265382                    -0.666101
# 4  1.658107                     1.505833
#
#    Experience in Years Previous Positions  Goals Score  Competency Score  \
# 0                                0.597193     0.639453          0.728677
# 1                               -0.516742    -0.396366          0.357783
# 2                                0.225881    -0.766302         -0.738894
# 3                                1.092276    -0.396366         -0.925196
# 4                                1.711129     0.812089          0.504965
#
#    Cultural Value Score  Additional Accomplishment Score  \
# 0              0.884639                         0.656303
# 1             -0.461913                        -1.204903
# 2             -1.094544                         0.973903
# 3             -0.183925                         0.188440
# 4              1.065007                        -0.863398
#
#    Potential Assessment Score  Trait Assessment Score
# 0                    0.436509                0.462198
# 1                   -0.334448                0.444873
# 2                   -1.010668               -1.597004
# 3                   -0.099517               -0.620000
# 4                    1.111555               -0.088562

# %% [markdown]
# ### PCA

# %%
from sklearn.decomposition import PCA
import numpy as np
import matplotlib.pyplot as plt

# %%
df_con.head()
# Out:
#    Technical Score_JD  Programming Score_JD  Soft Score_with_JD  \
# 0            1.565223              0.111923           -0.227219
# 1           -0.340456              0.388721            0.214140
# 2            0.893030              0.111923            2.001321
# 3            1.147216             -0.674252            1.701759
# 4           -0.785155             -0.674252           -0.194284
#
#    Education_match_Score_with_JD  Years of Experience in this Company  \
# 0                      -0.421820                            -0.590303
# 1                       0.108914                            -0.455248
# 2                       0.262900                            -0.995468
# 3                       0.396675                            -0.995468
# 4                       2.156105                             0.625192
#
#         KPI  Employee Satisfaction Score  \
# 0 -0.233031                     0.276858
# 1 -0.471827                    -1.028983
# 2 -1.425184                     0.269708
# 3 -1.265382                    -0.666101
# 4  1.658107                     1.505833
#
#    Experience in Years Previous Positions  Goals Score  Competency Score  \
# 0                                0.597193     0.639453          0.728677
# 1                               -0.516742    -0.396366          0.357783
# 2                                0.225881    -0.766302         -0.738894
# 3                                1.092276    -0.396366         -0.925196
# 4                                1.711129     0.812089          0.504965
#
#    Cultural Value Score  Additional Accomplishment Score  \
# 0              0.884639                         0.656303
# 1             -0.461913                        -1.204903
# 2             -1.094544                         0.973903
# 3             -0.183925                         0.188440
# 4              1.065007                        -0.863398
#
#    Potential Assessment Score  Trait Assessment Score
# 0                    0.436509                0.462198
# 1                   -0.334448                0.444873
# 2                   -1.010668               -1.597004
# 3                   -0.099517               -0.620000
# 4                    1.111555               -0.088562

# %%
pca=PCA()
pca.fit(df_con)
# Out:
# PCA()

# %%
eigenvalues=pca.explained_variance_
print(eigenvalues)
# Out:
# [3.68183309 2.45994268 1.37102205 1.17722941 1.08145188 1.03793397
#  0.89813845 0.69082966 0.59018512 0.33758781 0.3105454  0.22174472
#  0.1340172  0.06611598]

# %%
n_components = np.sum(eigenvalues > 1)
print(f"Number of components with eigenvalue > 1: {n_components}")

# Optional: Plot the eigenvalues to visualize the decision
plt.plot(range(1, len(eigenvalues) + 1), eigenvalues, marker='o')
plt.axhline(y=1, color='r', linestyle='--')  # Draw line at eigenvalue = 1
plt.xlabel('Component Number')
plt.ylabel('Eigenvalue')
plt.title('Eigenvalue vs Component Number (Kaiser Criterion)')
plt.show()
# Out:
# Number of components with eigenvalue > 1: 6

# %%
total_va=(eigenvalues[:n_components].sum()/eigenvalues.sum())*100
print(total_va)
# Out:
# 76.88838468297921

# %%
explain=pca.explained_variance_ratio_
print(explain)
# Out:
# [0.26189229 0.17497807 0.0975221  0.08373745 0.0769247  0.07382923
#  0.06388544 0.04913937 0.04198043 0.02401294 0.02208939 0.01577291
#  0.00953277 0.00470289]

# %%
eigenvector=pca.components_
print(eigenvector.shape)
eigen_df=pd.DataFrame(eigenvector,columns=[f'PCA{i+1}' for i in range(df_con.shape[1])])
eigen_df.head(5)
# Out:
# (14, 14)
#        PCA1      PCA2      PCA3      PCA4      PCA5      PCA6      PCA7  \
# 0 -0.105382 -0.087335  0.000409 -0.060505  0.317475  0.440821  0.156496
# 1  0.004527  0.082757  0.087806  0.128969  0.010635 -0.046113  0.519546
# 2  0.676569  0.645216  0.034943  0.141307  0.175001  0.026931 -0.106114
# 3  0.063448  0.167586 -0.002423  0.237950 -0.543894  0.032093  0.175818
# 4  0.060753 -0.090053  0.619423 -0.488464 -0.071866  0.030582  0.047399
#
#        PCA8      PCA9     PCA10     PCA11     PCA12     PCA13     PCA14
# 0  0.148980  0.414449  0.430602  0.163896  0.035583  0.449105  0.220898
# 1 -0.114635 -0.236959 -0.084414  0.568296 -0.027554 -0.221155  0.497568
# 2 -0.128598  0.024199  0.159505 -0.000488  0.130147  0.050939 -0.007343
# 3  0.594687  0.253058 -0.250793  0.120474  0.227866  0.165647 -0.095061
# 4 -0.129872  0.023751 -0.068370  0.015134  0.577816 -0.012913 -0.034634

# %%
selected_eigenvectors = pd.DataFrame(eigenvector[:,:n_components], columns=[f'PCA{i+1}' for i in range(n_components)])
selected_eigenvectors.head()
# Out:
#        PCA1      PCA2      PCA3      PCA4      PCA5      PCA6
# 0 -0.105382 -0.087335  0.000409 -0.060505  0.317475  0.440821
# 1  0.004527  0.082757  0.087806  0.128969  0.010635 -0.046113
# 2  0.676569  0.645216  0.034943  0.141307  0.175001  0.026931
# 3  0.063448  0.167586 -0.002423  0.237950 -0.543894  0.032093
# 4  0.060753 -0.090053  0.619423 -0.488464 -0.071866  0.030582

# %%
selected=eigenvalues[:n_components]
print(selected)
# Out:
# [3.68183309 2.45994268 1.37102205 1.17722941 1.08145188 1.03793397]

# %%
Normalize_eigenvector = np.abs(selected_eigenvectors) / np.sum(np.abs(selected_eigenvectors))
Normalize_eigenvector
# Out:
# c:\Users\DanukaDilshanRathnay\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\_core\fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
#         PCA1      PCA2      PCA3      PCA4      PCA5      PCA6
# 0   0.046943  0.035191  0.000202  0.024467  0.113381  0.201243
# 1   0.002017  0.033347  0.043373  0.052153  0.003798  0.021051
# 2   0.301378  0.259987  0.017261  0.057142  0.062499  0.012294
# 3   0.028263  0.067528  0.001197  0.096223  0.194243  0.014651
# 4   0.027063  0.036286  0.305975  0.197526  0.025666  0.013961
# 5   0.072801  0.057504  0.325207  0.134671  0.069364  0.071761
# 6   0.056049  0.096775  0.020826  0.284050  0.024253  0.020114
# 7   0.086922  0.110268  0.200754  0.095029  0.119865  0.081422
# 8   0.293677  0.246528  0.028932  0.002878  0.091075  0.033883
# 9   0.022051  0.014080  0.008989  0.018935  0.034240  0.067517
# 10  0.020573  0.002864  0.023594  0.004399  0.016167  0.381565
# 11  0.022661  0.009395  0.013298  0.017668  0.204396  0.051635
# 12  0.010515  0.024761  0.004097  0.009095  0.032019  0.027482
# 13  0.009088  0.005485  0.006295  0.005763  0.009034  0.001419

# %%
selected_ra=eigenvalues[:n_components]/eigenvalues.sum()
print(selected_ra)
# Out:
# [0.26189229 0.17497807 0.0975221  0.08373745 0.0769247  0.07382923]

# %%
eigen_loadings = pd.DataFrame(Normalize_eigenvector.values, index=df_con.columns, columns=[f'pca{i+1}' for i in range(n_components)])
eigen_loadings.head(21)
# Out:
#                                             pca1      pca2      pca3  \
# Technical Score_JD                      0.046943  0.035191  0.000202
# Programming Score_JD                    0.002017  0.033347  0.043373
# Soft Score_with_JD                      0.301378  0.259987  0.017261
# Education_match_Score_with_JD           0.028263  0.067528  0.001197
# Years of Experience in this Company     0.027063  0.036286  0.305975
# KPI                                     0.072801  0.057504  0.325207
# Employee Satisfaction Score             0.056049  0.096775  0.020826
# Experience in Years Previous Positions  0.086922  0.110268  0.200754
# Goals Score                             0.293677  0.246528  0.028932
# Competency Score                        0.022051  0.014080  0.008989
# Cultural Value Score                    0.020573  0.002864  0.023594
# Additional Accomplishment Score         0.022661  0.009395  0.013298
# Potential Assessment Score              0.010515  0.024761  0.004097
# Trait Assessment Score                  0.009088  0.005485  0.006295
#
#                                             pca4      pca5      pca6
# Technical Score_JD                      0.024467  0.113381  0.201243
# Programming Score_JD                    0.052153  0.003798  0.021051
# Soft Score_with_JD                      0.057142  0.062499  0.012294
# Education_match_Score_with_JD           0.096223  0.194243  0.014651
# Years of Experience in this Company     0.197526  0.025666  0.013961
# KPI                                     0.134671  0.069364  0.071761
# Employee Satisfaction Score             0.284050  0.024253  0.020114
# Experience in Years Previous Positions  0.095029  0.119865  0.081422
# Goals Score                             0.002878  0.091075  0.033883
# Competency Score                        0.018935  0.034240  0.067517
# Cultural Value Score                    0.004399  0.016167  0.381565
# Additional Accomplishment Score         0.017668  0.204396  0.051635
# Potential Assessment Score              0.009095  0.032019  0.027482
# Trait Assessment Score                  0.005763  0.009034  0.001419

# %%
def generate_pca_equation_dict(loadings_array, feature_names):
    # Convert to DataFrame for ease of processing
    loading_df = pd.DataFrame(loadings_array, columns=[f"PCA{i+1}" for i in range(loadings_array.shape[1])], index=feature_names)

    pca_equation_dict = {}

    # Iterate through each PCA component
    for pca in loading_df.columns:
        terms = []
        for feature, loading in loading_df[pca].items():
            terms.append(f"{loading:.5f} * df_con['{feature}']")  # Format coefficients
        equation = " + ".join(terms)
        pca_equation_dict[pca] = equation

    return pca_equation_dict


# Generate the equation dictionary
feature_names = eigen_loadings.index  # Ensure correct feature names
pca_equations = generate_pca_equation_dict(eigen_loadings.values, feature_names)

# Print the generated PCA equations
for pca, eq in pca_equations.items():
    print(f"{pca}= {eq}\n")
# Out:
# PCA1= 0.04694 * df_con['Technical Score_JD'] + 0.00202 * df_con['Programming Score_JD'] + 0.30138 * df_con['Soft Score_with_JD'] + 0.02826 * df_con['Education_match_Score_with_JD'] + 0.02706 * df_con['Years of Experience in this Company'] + 0.07280 * df_con['KPI'] + 0.05605 * df_con['Employee Satisfaction Score'] + 0.08692 * df_con['Experience in Years Previous Positions'] + 0.29368 * df_con['Goals Score'] + 0.02205 * df_con['Competency Score'] + 0.02057 * df_con['Cultural Value Score'] + 0.02266 * df_con['Additional Accomplishment Score'] + 0.01051 * df_con['Potential Assessment Score'] + 0.00909 * df_con['Trait Assessment Score']
#
# PCA2= 0.03519 * df_con['Technical Score_JD'] + 0.03335 * df_con['Programming Score_JD'] + 0.25999 * df_con['Soft Score_with_JD'] + 0.06753 * df_con['Education_match_Score_with_JD'] + 0.03629 * df_con['Years of Experience in this Company'] + 0.05750 * df_con['KPI'] + 0.09678 * df_con['Employee Satisfaction Score'] + 0.11027 * df_con['Experience in Years Previous Positions'] + 0.24653 * df_con['Goals Score'] + 0.01408 * df_con['Competency Score'] + 0.00286 * df_con['Cultural Value Score'] + 0.00939 * df_con['Additional Accomplishment Score'] + 0.02476 * df_con['Potential Assessment Score'] + 0.00548 * df_con['Trait Assessment Score']
#
# PCA3= 0.00020 * df_con['Technical Score_JD'] + 0.04337 * df_con['Programming Score_JD'] + 0.01726 * df_con['Soft Score_with_JD'] + 0.00120 * df_con['Education_match_Score_with_JD'] + 0.30597 * df_con['Years of Experience in this Company'] + 0.32521 * df_con['KPI'] + 0.02083 * df_con['Employee Satisfaction Score'] + 0.20075 * df_con['Experience in Years Previous Positions'] + 0.02893 * df_con['Goals Score'] + 0.00899 * df_con['Competency Score'] + 0.02359 * df_con['Cultural Value Score'] + 0.01330 * df_con['Additional Accomplishment Score'] + 0.00410 * df_con['Potential Assessment Score'] + 0.00630 * df_con['Trait Assessment Score']
#
# PCA4= 0.02447 * df_con['Technical Score_JD'] + 0.05215 * df_con['Programming Score_JD'] + 0.05714 * df_con['Soft Score_with_JD'] + 0.09622 * df_con['Education_match_Score_with_JD'] + 0.19753 * df_con['Years of Experience in this Company'] + 0.13467 * df_con['KPI'] + 0.28405 * df_con['Employee Satisfaction Score'] + 0.09503 * df_con['Experience in Years Previous Positions'] + 0.00288 * df_con['Goals Score'] + 0.01894 * df_con['Competency Score'] + 0.00440 * df_con['Cultural Value Score'] + 0.01767 * df_con['Additional Accomplishment Score'] + 0.00910 * df_con['Potential Assessment Score'] + 0.00576 * df_con['Trait Assessment Score']
#
# PCA5= 0.11338 * df_con['Technical Score_JD'] + 0.00380 * df_con['Programming Score_JD'] + 0.06250 * df_con['Soft Score_with_JD'] + 0.19424 * df_con['Education_match_Score_with_JD'] + 0.02567 * df_con['Years of Experience in this Company'] + 0.06936 * df_con['KPI'] + 0.02425 * df_con['Employee Satisfaction Score'] + 0.11986 * df_con['Experience in Years Previous Positions'] + 0.09107 * df_con['Goals Score'] + 0.03424 * df_con['Competency Score'] + 0.01617 * df_con['Cultural Value Score'] + 0.20440 * df_con['Additional Accomplishment Score'] + 0.03202 * df_con['Potential Assessment Score'] + 0.00903 * df_con['Trait Assessment Score']
#
# PCA6= 0.20124 * df_con['Technical Score_JD'] + 0.02105 * df_con['Programming Score_JD'] + 0.01229 * df_con['Soft Score_with_JD'] + 0.01465 * df_con['Education_match_Score_with_JD'] + 0.01396 * df_con['Years of Experience in this Company'] + 0.07176 * df_con['KPI'] + 0.02011 * df_con['Employee Satisfaction Score'] + 0.08142 * df_con['Experience in Years Previous Positions'] + 0.03388 * df_con['Goals Score'] + 0.06752 * df_con['Competency Score'] + 0.38157 * df_con['Cultural Value Score'] + 0.05163 * df_con['Additional Accomplishment Score'] + 0.02748 * df_con['Potential Assessment Score'] + 0.00142 * df_con['Trait Assessment Score']

# %%
suitability_equations = []

for i, (pca, equation) in enumerate(pca_equations.items()):
    if i < len(selected_ra):
        suitability = f"{selected_ra[i]:.5f} *  ({equation})"
        #suitability = f"({equation})"
        suitability_equations.append(suitability)
        

# Combine all equations into one final equation
final_equation = " + ".join(suitability_equations)

print("Final Suitability Equation:\n", final_equation)
# Out:
# Final Suitability Equation:
#  0.26189 *  (0.04694 * df_con['Technical Score_JD'] + 0.00202 * df_con['Programming Score_JD'] + 0.30138 * df_con['Soft Score_with_JD'] + 0.02826 * df_con['Education_match_Score_with_JD'] + 0.02706 * df_con['Years of Experience in this Company'] + 0.07280 * df_con['KPI'] + 0.05605 * df_con['Employee Satisfaction Score'] + 0.08692 * df_con['Experience in Years Previous Positions'] + 0.29368 * df_con['Goals Score'] + 0.02205 * df_con['Competency Score'] + 0.02057 * df_con['Cultural Value Score'] + 0.02266 * df_con['Additional Accomplishment Score'] + 0.01051 * df_con['Potential Assessment Score'] + 0.00909 * df_con['Trait Assessment Score']) + 0.17498 *  (0.03519 * df_con['Technical Score_JD'] + 0.03335 * df_con['Programming Score_JD'] + 0.25999 * df_con['Soft Score_with_JD'] + 0.06753 * df_con['Education_match_Score_with_JD'] + 0.03629 * df_con['Years of Experience in this Company'] + 0.05750 * df_con['KPI'] + 0.09678 * df_con['Employee Satisfaction Score'] + 0.11027 * df_con['Experience in Years Previous Positions'] + 0.24653 * df_con['Goals Score'] + 0.01408 * df_con['Competency Score'] + 0.00286 * df_con['Cultural Value Score'] + 0.00939 * df_con['Additional Accomplishment Score'] + 0.02476 * df_con['Potential Assessment Score'] + 0.00548 * df_con['Trait Assessment Score']) + 0.09752 *  (0.00020 * df_con['Technical Score_JD'] + 0.04337 * df_con['Programming Score_JD'] + 0.01726 * df_con['Soft Score_with_JD'] + 0.00120 * df_con['Education_match_Score_with_JD'] + 0.30597 * df_con['Years of Experience in this Company'] + 0.32521 * df_con['KPI'] + 0.02083 * df_con['Employee Satisfaction Score'] + 0.20075 * df_con['Experience in Years Previous Positions'] + 0.02893 * df_con['Goals Score'] + 0.00899 * df_con['Competency Score'] + 0.02359 * df_con['Cultural Value Score'] + 0.01330 * df_con['Additional Accomplishment Score'] + 0.00410 * df_con['Potential Assessment Score'] + 0.00630 * df_con['Trait Assessment Score']) + 0.08374 *  (0.02447 * df_con['Technical Score_JD'] + 0.05215 * df_con['Programming Score_JD'] + 0.05714 * df_con['Soft Score_with_JD'] + 0.09622 * df_con['Education_match_Score_with_JD'] + 0.19753 * df_con['Years of Experience in this Company'] + 0.13467 * df_con['KPI'] + 0.28405 * df_con['Employee Satisfaction Score'] + 0.09503 * df_con['Experience in Years Previous Positions'] + 0.00288 * df_con['Goals Score'] + 0.01894 * df_con['Competency Score'] + 0.00440 * df_con['Cultural Value Score'] + 0.01767 * df_con['Additional Accomplishment Score'] + 0.00910 * df_con['Potential Assessment Score'] + 0.00576 * df_con['Trait Assessment Score']) + 0.07692 *  (0.11338 * df_con['Technical Score_JD'] + 0.00380 * df_con['Programming Score_JD'] + 0.06250 * df_con['Soft Score_with_JD'] + 0.19424 * df_con['Education_match_Score_with_JD'] + 0.02567 * df_con['Years of Experience in this Company'] + 0.06936 * df_con['KPI'] + 0.02425 * df_con['Employee Satisfaction Score'] + 0.11986 * df_con['Experience in Years Previous Positions'] + 0.09107 * df_con['Goals Score'] + 0.03424 * df_con['Competency Score'] + 0.01617 * df_con['Cultural Value Score'] + 0.20440 * df_con['Additional Accomplishment Score'] + 0.03202 * df_con['Potential Assessment Score'] + 0.00903 * df_con['Trait Assessment Score']) + 0.07383 *  (0.20124 * df_con['Technical Score_JD'] + 0.02105 * df_con['Programming Score_JD'] + 0.01229 * df_con['Soft Score_with_JD'] + 0.01465 * df_con['Education_match_Score_with_JD'] + 0.01396 * df_con['Years of Experience in this Company'] + 0.07176 * df_con['KPI'] + 0.02011 * df_con['Employee Satisfaction Score'] + 0.08142 * df_con['Experience in Years Previous Positions'] + 0.03388 * df_con['Goals Score'] + 0.06752 * df_con['Competency Score'] + 0.38157 * df_con['Cultural Value Score'] + 0.05163 * df_con['Additional Accomplishment Score'] + 0.02748 * df_con['Potential Assessment Score'] + 0.00142 * df_con['Trait Assessment Score'])

# %%
processed_df = pd.concat([employee_ids.reset_index(drop=True), df_con], axis=1)

# %%
processed_df ["Suitability_score"]=eval(final_equation)

# %%
processed_df .shape
# Out:
# (240, 16)

# %%
processed_df ["Suitability_score_scaled"]=mn.fit_transform(processed_df [["Suitability_score"]])

# %%
processed_df .columns
# Out:
# Index(['EmployeeCode', 'Technical Score_JD', 'Programming Score_JD',
#        'Soft Score_with_JD', 'Education_match_Score_with_JD',
#        'Years of Experience in this Company', 'KPI',
#        'Employee Satisfaction Score', 'Experience in Years Previous Positions',
#        'Goals Score', 'Competency Score', 'Cultural Value Score',
#        'Additional Accomplishment Score', 'Potential Assessment Score',
#        'Trait Assessment Score', 'Suitability_score',
#        'Suitability_score_scaled'],
#       dtype='object')

# %%
dfk=processed_df [["EmployeeCode","Suitability_score","Suitability_score_scaled"]]

# %%
dfg=pd.read_excel('C://Users//DanukaDilshanRathnay//Desktop//AI-Driven-Job-Role-Fit-Prediction//code//Dataset//Similarity_with_EMP_data.xlsx')

# %%
dfff=dfk.merge(dfg, on='EmployeeCode',how='left')

# %%
dfff.to_excel("xx.xlsx",index=False)

# %%
dfff.head()
# Out:
#   EmployeeCode  Suitability_score  Suitability_score_scaled  \
# 0      EMP9004           0.192009                  0.600855
# 1      EMP9005          -0.250013                  0.367111
# 2      EMP9009           0.032294                  0.516396
# 3      EMP9015           0.098482                  0.551397
# 4      EMP9021           0.579548                  0.805788
#
#    Technical Score_JD  Programming Score_JD  Soft Score_with_JD  \
# 0            0.514297              0.722849            0.379506
# 1            0.229454              0.787505            0.420458
# 2            0.413824              0.722849            0.586283
# 3            0.451817              0.539208            0.558488
# 4            0.162984              0.539208            0.382562
#
#    Education_match_Score_with_JD  Gender  Age   Department  ...  \
# 0                       0.614774    Male   41  Data and AI  ...
# 1                       0.644765  Female   33  Data and AI  ...
# 2                       0.653466    Male   35  Data and AI  ...
# 3                       0.661025    Male   42  Data and AI  ...
# 4                       0.760446    Male   59  Data and AI  ...
#
#   Total Experience in Years Number of Goal Assigned Number of Goals Achieved  \
# 0                        19                      10                        7
# 1                        11                      10                        5
# 2                        13                       7                        3
# 3                        20                      10                        5
# 4                        37                      15                       11
#
#    Final Score Goals Score Competency Score Cultural Value Score  \
# 0    35.000000   70.000000        34.180251            76.488103
# 1    35.000000   50.000000        30.775600            63.895969
# 2    35.000000   42.857143        20.708582            57.979997
# 3    35.000000   50.000000        18.998407            66.495545
# 4    56.717347   73.333333        32.126666            78.174790
#
#    Additional Accomplishment Score  Potential Assessment Score  \
# 0                             7.08                   51.806653
# 1                             1.63                   40.425636
# 2                             8.01                   30.443135
# 3                             5.71                   43.893732
# 4                             2.63                   61.771810
#
#    Trait Assessment Score
# 0               55.141563
# 1               54.988743
# 2               36.977535
# 3               45.595596
# 4               50.283365
#
# [5 rows x 31 columns]

# %%
dfff.to_excel("finalfinal.xlsx",index=False)

# %%
df1=pd.read_excel('C://Users//DanukaDilshanRathnay//Desktop//AI-Driven-Job-Role-Fit-Prediction//com//x.xlsx')
df2=pd.read_excel('C://Users//DanukaDilshanRathnay//Desktop//AI-Driven-Job-Role-Fit-Prediction//com//x_train.xlsx')

# %%
dfm=pd.concat([df1,df2],axis=0)

# %%
df_jd=dfm[['EmployeeCode','JD match Score']]

# %%
df_jd.head()
# Out:
#   EmployeeCode  JD match Score
# 0      EMP9449        0.653565
# 1      EMP9798        0.627276
# 2      EMP9271        0.606090
# 3      EMP9931        0.498329
# 4      EMP9213        0.562582

# %%
df_my=df_jd.merge(dfff[['EmployeeCode','Suitability_score','Suitability_score_scaled']],on="EmployeeCode")

# %%
df_my.head()
# Out:
#   EmployeeCode  JD match Score  Suitability_score  Suitability_score_scaled
# 0      EMP9449        0.653565           0.094108                  0.549084
# 1      EMP9798        0.627276          -0.054964                  0.470254
# 2      EMP9271        0.606090           0.252587                  0.632889
# 3      EMP9931        0.498329          -0.480354                  0.245304
# 4      EMP9213        0.562582           0.056990                  0.529456

# %%
df_my["disimilarity"]=1-df_my['JD match Score']

# %%
df_my.columns
# Out:
# Index(['EmployeeCode', 'JD match Score', 'Suitability_score',
#        'Suitability_score_scaled', 'disimilarity'],
#       dtype='object')

# %%
df_my[['Suitability_score', 'disimilarity']].corr()
# Out:
#                    Suitability_score  disimilarity
# Suitability_score            1.00000      -0.34675
# disimilarity                -0.34675       1.00000

# %%
df_my.to_excel("PCA_score.xlsx",index=False)

# %%
eigen_loadings=eigen_loadings*selected_ra

# %%
feature_importance = np.abs(eigen_loadings)  # Take absolute value for importance
overall_importance = feature_importance.sum(axis=1)  # Sum across rows (principal components)

# Normalize to percentages
overall_importance_percentages = (overall_importance / overall_importance.sum()) 

# Sort feature importances in descending order
sorted_indices = np.argsort(overall_importance_percentages)[::-1]  # Sort indices in descending order

# Print overall feature importance as percentages with column names in descending order
print("\nOverall Feature Importance (as %):")
for idx in sorted_indices:
    print(f"{df_con.columns[idx]}: {overall_importance_percentages[idx]:.2f}")
# Out:
# Overall Feature Importance (as %):
# Soft Score_with_JD: 0.18
# Goals Score: 0.17
# Experience in Years Previous Positions: 0.11
# KPI: 0.11
# Years of Experience in this Company: 0.08
# Employee Satisfaction Score: 0.08
# Technical Score_JD: 0.06
# Education_match_Score_with_JD: 0.06
# Cultural Value Score: 0.05
# Additional Accomplishment Score: 0.04
# Competency Score: 0.02
# Programming Score_JD: 0.02
# Potential Assessment Score: 0.02
# Trait Assessment Score: 0.01
# C:\Users\DanukaDilshanRathnay\AppData\Local\Temp\ipykernel_23980\4167550042.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(f"{df_con.columns[idx]}: {overall_importance_percentages[idx]:.2f}")

# %%
data.to_excel("dd.xlsx")
